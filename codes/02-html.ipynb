# %% [markdown]
# ## Hypertext Markup Language (HTML)
#
# Selon wikipedia[^1]
#
# - Ce langage permet d’écrire de l’hypertexte (d’où son nom), de structurer sémantiquement une page web, de mettre en forme du contenu, de créer des formulaires de saisie ou encore d’inclure des ressources multimédias dont des images, des vidéos, et des programmes informatiques.
#
# - Le HTML offre également la possibilité de créer des documents interopérables avec des équipements très variés et conformément aux exigences de l’accessibilité du web.
#
#
# [^1]: [Wikipedia](https://fr.wikipedia.org/wiki/Hypertext_Markup_Language)

# %% [markdown]
# ### Structure de base

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#       <meta charset="UTF-8">
#       <title>Titre onglet</title>
#   </head>
#   <body>
#       <h1>Titre de niveau 1</h1>
#       <h3>Titre de niveau 3</h3>
#       <p>Paragraphe</p>
#       <h3>Liste numerotée :</h3>
#       <ol>
#           <li>python</li>
#           <li>linux</li>
#           <li>pycharm</li>
#       </ol>
#       <h3>Puces classiques:</h3>
#       <ul>
#           <li>python</li>
#           <li>linux</li>
#       </ul>
#       <a href="www.google.com"> Google </a>
#       <img src="assets/logo.jpeg" width="150" alt="Python Logo">
#   </body>
# </html>

# %% [markdown]
# ###  Liste numérotée et puces

# %% [markdown]
# <body>
#     <h3>Liste numerotée :</h3>
#     <ol>
#         <li>python</li>
#         <li>linux</li>
#         <li>pycharm</li>
#     </ol>
#     <h3>Puces classiques:</h3>
#     <ul>
#         <li>python</li>
#         <li>linux</li>
#     </ul>
#     <a href="www.google.com"> Google </a>
# </body>

# %% [markdown]
# ### Images et Liens

# %% [markdown]
# <body>
#     <img src="./assets/logo.jpeg" width="150" alt="Python Logo">
#     <br>
#     <br> <a href="01_next_page.html">Page suivante</a>
#     <br> <a href="./02_table.html">Page table</a>
#     <br> <a href="./03_input.html">Page formulaire</a>
#     <br> <a href="./04_style.html">Page style CSS</a>
#     <br> <a href="http://www.google.com">Google.com</a>
# </body>

# %% [markdown]
# ### Tableau

# %% [markdown]
# <body>
#     <table border="1">
#         <thead>
#             <th>UserID</th>
#             <th>Rating</th>
#             <th>Age</th>
#         </thead>
#         <tr>
#             <td>001</td>
#             <td>4.5</td>
#             <td>25</td>
#         </tr>
#         <tr>
#             <td>002</td>
#             <td>4</td>
#             <td>23</td>
#         </tr>
#         <tr>
#             <td>003</td>
#             <td>5</td>
#             <td>21</td>
#         </tr>
#     </table>
# </body>

# %% [markdown]
# thead== table head
# tr== table row

# %% [markdown]
# ### Formulaire

# %% [markdown]
# <body>
#     <form>
#         <h3>Exemple de formulaire :</h3>
#         <input id="name" type="text" placeholder="Nom et prénom"> Nom et prénom <br> <br>
#         <input type="email" value="mail@exemple.com"> Email <br> <br>
#         <input type="date"> Date de souscription <br> <br>
#         <input type="checkbox" name="permis" > Avez-vous le permis de conduire <br> <br>
#         <input type="number"> Nombre de vélos <br> <br>
#         <input type="password"> Mots de passe <br> <br>
#     </form>
# </body>

# %% [markdown]
# ### Style css

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <style>
#         .style-1 {
#             font-family: Arial;
#             font-size: 20px;
#             background: #1EAEDB;
#             width: 100px;
#         }
#         .test {
#             color : red;
#             font-size ; 40px
#         }
#     </style>
#     <link rel="stylesheet" href="assets/styles.css">
#     <title>Titre onglet</title>
# </head>
# <body>
#     <h1 style="color: red; font-size: 40px">Page avec plus de style</h1>
#     <ol>
#         <li style="font-family: Arial; font-weight: bold">python</li>
#         <li class="style-1">linux</li>
#         <li class="test">pycharm</li>
#     </ol>
# </body>
# </hrml>

# %% [markdown]
# ### Exercice :
#
# 1. Créez une cellule **markdown**.
#
# 2. Ajoutez un formulaire demandant à l'utilisateur son nom, prénom, adresse e-mail et âge.
#
# 3. Ajoutez une liste à puces dans laquelle vous pouvez énumérer trois de vos passe-temps préférés.
#
# 4. Créez un tableau de produits contenant trois produits pris aléatoirement avec les colonnes suivantes : Nom du produit, Prix, Quantité.

# %% [markdown]
# <body>
#     <form>
#         <h3>Formulaire :</h3>
#         <input id="name" type="text" placeholder="Nom et prénom"> Nom et prénom <br> <br>
#         <input type="email" value="mail@exemple.com"> Email <br> <br>
#         <input type="number"> Âge <br> <br>
#     </form>
#     <h3>Passe-temps :</h3>
#     <ul>
#         <li>python</li>
#         <li>linux</li>
#         <li>pycharm</li>
#     </ul>
#     <h3>Tableau de produits :</h3>
#     <table border="1">
#         <thead>
#             <th>Nom du produit</th>
#             <th>Prix</th>
#             <th>Quantité</th>
#         </thead>
#         <tr>
#             <td>Produit 1</td>
#             <td>100</td>
#             <td>10</td>
#         </tr>
#         <tr>
#             <td>Produit 2</td>
#             <td>200</td>
#             <td>20</td>
#         </tr>
#     </table>
# </body>
